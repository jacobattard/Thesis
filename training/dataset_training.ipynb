# %% [markdown]
# # Dataset

# %%
from roboflow import Roboflow

rf = Roboflow(api_key="QmzA8vyVJAsptHIaUGx5")
project = rf.workspace("penalty-detection").project("handball-detection-op71z")
version = project.version(8)
dataset = version.download("yolov11")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to handball-detection-8 in yolov11:: 100%|██████████| 4654/4654 [00:02<00:00, 2018.63it/s]

# %%
import shutil

shutil.move("handball-detection-7/test", "handball-detection-7/handball-detection-7/test")
shutil.move("handball-detection-7/train", "handball-detection-7/handball-detection-7/train")
shutil.move("handball-detection-7/valid", "handball-detection-7/handball-detection-7/valid")
# Out:
# 'handball-detection-7/handball-detection-7/valid'

# %%
# !yolo task=detect mode=train model=yolo11n.pt data=C:/Users/Jacob/Desktop/Thesis/Code/training/handball-detection-8/data.yaml epochs=10 batch=16 device=0
# Out:
# New https://pypi.org/project/ultralytics/8.3.85 available 😃 Update with 'pip install -U ultralytics'
# train: Scanning C:\Users\Jacob\Desktop\Thesis\Code\training\handball-detection-8\train\labels...:   0%|          | 0/2058 [00:00<?, ?it/s]
# train: Scanning C:\Users\Jacob\Desktop\Thesis\Code\training\handball-detection-8\train\labels... 83 images, 0 backgrounds, 0 corrupt:   4%|▍         | 83/2058 [00:00<00:02, 814.89it/s]
# train: Scanning C:\Users\Jacob\Desktop\Thesis\Code\training\handball-detection-8\train\labels... 179 images, 0 backgrounds, 0 corrupt:   9%|▊         | 179/2058 [00:00<00:02, 890.16it/s]
# train: Scanning C:\Users\Jacob\Desktop\Thesis\Code\training\handball-detection-8\train\labels... 277 images, 0 backgrounds, 0 corrupt:  13%|█▎        | 277/2058 [00:00<00:01, 927.02it/s]
# train: Scanning C:\Users\Jacob\Desktop\Thesis\Code\training\handball-detection-8\train\labels... 370 images, 0 backgrounds, 0 corrupt:  18%|█▊        | 370/2058 [00:00<00:01, 900.54it/s]
# ...

# %% [markdown]
# # Dataset

# %%
from roboflow import Roboflow

rf = Roboflow(api_key="QmzA8vyVJAsptHIaUGx5")
project = rf.workspace("penalty-detection").project("handball-detection-op71z")
version = project.version(2)
dataset = version.download("yolov11")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to handball-detection-2 in yolov11:: 100%|██████████| 2070/2070 [00:01<00:00, 1558.92it/s]

# %%
import shutil

shutil.move("handball-detection-2/test", "handball-detection-2/handball-detection-2/test")
shutil.move("handball-detection-2/train", "handball-detection-2/handball-detection-2/train")
shutil.move("handball-detection-2/valid", "handball-detection-2/handball-detection-2/valid")
# Out:
# 'handball-detection-2/handball-detection-2/valid'

# %%
# !yolo task=detect mode=train model=yolo11n.pt data=C:/Users/Jacob/Desktop/Thesis/Code/training/handball-detection-2/data.yaml epochs=10 batch=16 device=0
# Out:
# New https://pypi.org/project/ultralytics/8.3.74 available 😃 Update with 'pip install -U ultralytics'
# train: Scanning C:\Users\Jacob\Desktop\Thesis\Code\training\handball-detection-2\train\labels.cache... 721 images, 0 backgrounds, 0 corrupt: 100%|██████████| 721/721 [00:00<?, ?it/s]
# train: Scanning C:\Users\Jacob\Desktop\Thesis\Code\training\handball-detection-2\train\labels.cache... 721 images, 0 backgrounds, 0 corrupt: 100%|██████████| 721/721 [00:00<?, ?it/s]
#
# val: Scanning C:\Users\Jacob\Desktop\Thesis\Code\training\handball-detection-2\valid\labels.cache... 205 images, 0 backgrounds, 0 corrupt: 100%|██████████| 205/205 [00:00<?, ?it/s]
# val: Scanning C:\Users\Jacob\Desktop\Thesis\Code\training\handball-detection-2\valid\labels.cache... 205 images, 0 backgrounds, 0 corrupt: 100%|██████████| 205/205 [00:00<?, ?it/s]
#
#   0%|          | 0/46 [00:00<?, ?it/s]
# ...
